# %% [markdown]
# # Week 13 Homework

# %% [markdown]
# # Question 1:	Download the dataset here: https://www.kaggle.com/sohier/calcofi and create one DataFrame for the bottle file and another for the cast file. Perform preprocessing on this dataset. You do not need to do all six types of preprocessing we discussed. For this dataset, 2-3 is all you need.

# %%
# import necessary modules

import pandas as pd
import numpy as np

#create dataframes from the csv files
cast_df = pd.read_csv('./cast.csv')
bottle_df = pd.read_csv('./bottle.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (40,41,44,45,46,47) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (47,73) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
#get more information about the cast df
cast_df.head()
# Out:
#    Cst_Cnt          Cruise_ID  Cruise        Cruz_Sta  DbSta_ID  \
# 0        1  1949-03-01-C-31CR  194903  19490305400560   5400560
# 1        2  1949-03-01-C-31CR  194903  19490305200750   5200750
# 2        3  1949-03-01-C-31CR  194903  19490305100850   5100850
# 3        4  1949-03-01-C-31CR  194903  19490305000950   5000950
# 4        5  1949-03-01-C-31CR  194903  19490305001040   5001040
#
#                           Cast_ID       Sta_ID  Quarter Sta_Code  Distance  \
# 0  19-4903CR-HY-060-0930-05400560  054.0 056.0        1      NST       NaN
# 1  19-4903CR-HY-060-2112-05200750  052.0 075.0        1      NST       NaN
# 2  19-4903CR-HY-061-0354-05100850  051.0 085.0        1      NST       NaN
# 3  19-4903CR-HY-061-1042-05000950  050.0 095.0        1      NST       NaN
# 4  19-4903CR-HY-061-1706-05001040  050.0 104.0        1      NST       NaN
#
#    ... Wave_Prd  Wind_Dir  Wind_Spd  Barometer  Dry_T Wet_T  Wea  Cloud_Typ  \
# ...

# %%
#Look at the statistical distribution of each column of the dataset
cast_df.describe()
# Out:
#             Cst_Cnt         Cruise      Cruz_Sta      DbSta_ID       Quarter  \
# count  34404.000000   34404.000000  3.440400e+04  3.440400e+04  34404.000000
# mean   17202.500000  197406.030781  1.974061e+13  9.330342e+06      2.366556
# std     9931.723667    1974.562207  1.974557e+11  2.217993e+06      1.091894
# min        1.000000  194903.000000  1.949030e+13  1.016800e+05      1.000000
# 25%     8601.750000  195701.000000  1.957011e+13  8.100430e+06      1.000000
# 50%    17202.500000  196912.000000  1.969121e+13  9.000800e+06      2.000000
# 75%    25803.250000  198809.000000  1.988091e+13  1.067032e+07      3.000000
# max    34404.000000  201611.000000  2.016111e+13  1.767030e+07      4.000000
#
#            Distance         Year         Month   Julian_Date    Julian_Day  \
# count  19714.000000  34404.00000  34404.000000  34404.000000  34404.000000
# mean    -116.135017   1974.00218      5.835397  27017.612313    161.366236
# ...

# %%
#Find out total columns, number of null points per column and datatype for each column
cast_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34404 entries, 0 to 34403
# Data columns (total 61 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Cst_Cnt      34404 non-null  int64
#  1   Cruise_ID    34404 non-null  object
#  2   Cruise       34404 non-null  int64
#  3   Cruz_Sta     34404 non-null  int64
#  4   DbSta_ID     34404 non-null  int64
#  5   Cast_ID      34404 non-null  object
#  6   Sta_ID       34404 non-null  object
#  7   Quarter      34404 non-null  int64
#  8   Sta_Code     34404 non-null  object
#  9   Distance     19714 non-null  float64
#  10  Date         34404 non-null  object
#  11  Year         34404 non-null  int64
#  12  Month        34404 non-null  int64
#  13  Julian_Date  34404 non-null  int64
#  14  Julian_Day   34404 non-null  int64
#  15  Time         34080 non-null  object
#  16  Lat_Dec      34404 non-null  float64
#  17  Lat_Deg      34404 non-null  int64
# ...

# %%
#Look for repetitive columns to remove.  For example, Cruise_ID, Cruise, DB_StaID, Cast_ID and Sta_ID can all be removed since the info found in those columns is in Cruz_Sta.
cast_df[['Date', 'Year', 'Month', 'Julian_Date', 'Julian_Day', 'Time']].head()
# Out:
#          Date  Year  Month  Julian_Date  Julian_Day      Time
# 0  03/01/1949  1949      3        17958          60  09:30:00
# 1  03/01/1949  1949      3        17958          60  21:12:00
# 2  03/02/1949  1949      3        17959          61  03:54:00
# 3  03/02/1949  1949      3        17959          61  10:42:00
# 4  03/02/1949  1949      3        17959          61  17:06:00

# %%
# Date, year, month, and julian_day can all be dropped since they can be found using the julian_date. 
#Now look at location columns to see which ones are repetitve and can be dropped.

cast_df[['Lat_Dec', 'Lat_Deg', 'Lat_Min', 'Lat_Hem', 'Lon_Dec', 'Lon_Deg', 'Lon_Min', 'Lon_Hem']].head()
# Out:
#      Lat_Dec  Lat_Deg  Lat_Min Lat_Hem     Lon_Dec  Lon_Deg  Lon_Min Lon_Hem
# 0  38.833333       38     50.0       N -124.083333     -124      5.0       W
# 1  38.583333       38     35.0       N -125.800000     -125     48.0       W
# 2  38.475000       38     28.5       N -126.666666     -126     40.0       W
# 3  38.333333       38     20.0       N -127.516666     -127     31.0       W
# 4  38.233333       38     14.0       N -128.366666     -128     22.0       W

# %%
#Lon_Deg, Lat_Deg,Lat_Hem, and Lon_Hem can also be removed since they are reptitive from Lat_Dec and Lon_Dec
cast_df.iloc[:,24:48].head()
# Out:
#    Rpt_Line  St_Line  Ac_Line  Rpt_Sta  St_Station  Ac_Sta  Bottom_D  Secchi  \
# 0      54.0     54.0     53.8     56.0        56.0    55.8       NaN     NaN
# 1      52.0     52.0     51.5     75.0        75.0    75.1       NaN     NaN
# 2      51.0     51.0     50.3     85.0        85.0    84.7       NaN     NaN
# 3      50.0     50.0     49.2     95.0        95.0    94.3       NaN     NaN
# 4      50.0     50.0     48.0    104.0       104.0   103.7       NaN     NaN
#
#    ForelU Ship_Name  ... Cruz_Leg Orig_Sta_ID  Data_Or  Cruz_Num  IntChl  \
# 0     NaN     CREST  ...      NaN      054 56      NaN      4903     NaN
# 1     NaN     CREST  ...      NaN      052 75      NaN      4903     NaN
# 2     NaN     CREST  ...      NaN      051 85      NaN      4903     NaN
# 3     NaN     CREST  ...      NaN      050 95      NaN      4903     NaN
# 4     NaN     CREST  ...      NaN     050 104      NaN      4903     NaN
#
#   IntC14 Inc_Str Inc_End  PST_LAN  Civil_T
# ...

# %%
#After looking at columns, remove all columns that are repetitve or not necessary for our analysis and columns with lots of missing data. 
cast_df.drop(cast_df.iloc[:,24:48], axis=1, inplace=True)

# %%
cast_df.drop(cast_df.iloc[:, 0:2], axis=1, inplace=True)
cast_df.head()
# Out:
#    Cruise        Cruz_Sta  DbSta_ID                         Cast_ID  \
# 0  194903  19490305400560   5400560  19-4903CR-HY-060-0930-05400560
# 1  194903  19490305200750   5200750  19-4903CR-HY-060-2112-05200750
# 2  194903  19490305100850   5100850  19-4903CR-HY-061-0354-05100850
# 3  194903  19490305000950   5000950  19-4903CR-HY-061-1042-05000950
# 4  194903  19490305001040   5001040  19-4903CR-HY-061-1706-05001040
#
#         Sta_ID  Quarter Sta_Code  Distance        Date  Year  ...  Wave_Prd  \
# 0  054.0 056.0        1      NST       NaN  03/01/1949  1949  ...       NaN
# 1  052.0 075.0        1      NST       NaN  03/01/1949  1949  ...       NaN
# 2  051.0 085.0        1      NST       NaN  03/02/1949  1949  ...       NaN
# 3  050.0 095.0        1      NST       NaN  03/02/1949  1949  ...       NaN
# 4  050.0 104.0        1      NST       NaN  03/02/1949  1949  ...       NaN
#
#    Wind_Dir  Wind_Spd Barometer  Dry_T  Wet_T  Wea Cloud_Typ  Cloud_Amt  \
# ...

# %%
drop_columns = ['Cruise', 'DbSta_ID', 'Cast_ID', 'Sta_ID', 'Quarter', 'Sta_Code', 'Distance', 'Date', 'Year', 'Month', 'Julian_Day', 'Time', 'Lat_Deg', 'Lat_Min', 'Lat_Hem', 'Lon_Deg', 'Lon_Min', 'Lon_Hem', 'TimeZone']

# %%
cast_df.drop(drop_columns, axis=1, inplace=True)

# %%
cast_df.head()
# Out:
#          Cruz_Sta  Julian_Date    Lat_Dec     Lon_Dec  Wave_Dir  Wave_Ht  \
# 0  19490305400560        17958  38.833333 -124.083333       NaN      NaN
# 1  19490305200750        17958  38.583333 -125.800000       NaN      NaN
# 2  19490305100850        17959  38.475000 -126.666666       NaN      NaN
# 3  19490305000950        17959  38.333333 -127.516666       NaN      NaN
# 4  19490305001040        17959  38.233333 -128.366666       NaN      NaN
#
#    Wave_Prd  Wind_Dir  Wind_Spd  Barometer  Dry_T  Wet_T  Wea  Cloud_Typ  \
# 0       NaN      23.0      18.0        NaN    NaN    NaN  2.0        NaN
# 1       NaN      16.0       5.0        NaN    NaN    NaN  4.0        NaN
# 2       NaN      23.0       5.0        NaN    NaN    NaN  6.0        NaN
# 3       NaN      18.0       8.0        NaN    NaN    NaN  2.0        NaN
# 4       NaN      27.0      13.0        NaN    NaN    NaN  7.0        NaN
#
#    Cloud_Amt  Visibility
# 0        NaN         NaN
# 1        NaN         NaN
# ...

# %%
cast_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34404 entries, 0 to 34403
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Cruz_Sta     34404 non-null  int64
#  1   Julian_Date  34404 non-null  int64
#  2   Lat_Dec      34404 non-null  float64
#  3   Lon_Dec      34404 non-null  float64
#  4   Wave_Dir     12558 non-null  float64
#  5   Wave_Ht      12098 non-null  float64
#  6   Wave_Prd     11634 non-null  float64
#  7   Wind_Dir     32928 non-null  float64
#  8   Wind_Spd     32725 non-null  float64
#  9   Barometer    19063 non-null  float64
#  10  Dry_T        19071 non-null  float64
#  11  Wet_T        18989 non-null  float64
#  12  Wea          26807 non-null  float64
#  13  Cloud_Typ    9920 non-null   float64
#  14  Cloud_Amt    11882 non-null  float64
#  15  Visibility   9507 non-null   float64
# dtypes: float64(14), int64(2)
# memory usage: 4.2 MB

# %%
#Drop all rows with missing values
#new_df = (cast_df.drop([cast_df.isnull()==False], axis=0))
cast_df.dropna(axis=1, thresh=10000, inplace=True)

#drop rows with missing values
cast_df.dropna(axis=0, inplace=True)

# %%
cast_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9788 entries, 13971 to 34403
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Cruz_Sta     9788 non-null   int64
#  1   Julian_Date  9788 non-null   int64
#  2   Lat_Dec      9788 non-null   float64
#  3   Lon_Dec      9788 non-null   float64
#  4   Wave_Dir     9788 non-null   float64
#  5   Wave_Ht      9788 non-null   float64
#  6   Wave_Prd     9788 non-null   float64
#  7   Wind_Dir     9788 non-null   float64
#  8   Wind_Spd     9788 non-null   float64
#  9   Barometer    9788 non-null   float64
#  10  Dry_T        9788 non-null   float64
#  11  Wet_T        9788 non-null   float64
#  12  Wea          9788 non-null   float64
#  13  Cloud_Amt    9788 non-null   float64
# dtypes: float64(12), int64(2)
# memory usage: 1.1 MB

# %%
#Look at the bottle dataframe using describe, info, and head
bottle_df.head()
# Out:
#    Cst_Cnt  Btl_Cnt       Sta_ID                                Depth_ID  \
# 0        1        1  054.0 056.0  19-4903CR-HY-060-0930-05400560-0000A-3
# 1        1        2  054.0 056.0  19-4903CR-HY-060-0930-05400560-0008A-3
# 2        1        3  054.0 056.0  19-4903CR-HY-060-0930-05400560-0010A-7
# 3        1        4  054.0 056.0  19-4903CR-HY-060-0930-05400560-0019A-3
# 4        1        5  054.0 056.0  19-4903CR-HY-060-0930-05400560-0020A-7
#
#    Depthm  T_degC  Salnty  O2ml_L  STheta  O2Sat  ...  R_PHAEO  R_PRES  \
# 0       0   10.50  33.440     NaN  25.649    NaN  ...      NaN       0
# 1       8   10.46  33.440     NaN  25.656    NaN  ...      NaN       8
# 2      10   10.46  33.437     NaN  25.654    NaN  ...      NaN      10
# 3      19   10.45  33.420     NaN  25.643    NaN  ...      NaN      19
# 4      20   10.45  33.421     NaN  25.643    NaN  ...      NaN      20
#
#    R_SAMP  DIC1  DIC2  TA1  TA2  pH2  pH1  DIC Quality Comment
# ...

# %%
bottle_df.describe()
# Out:
#              Cst_Cnt        Btl_Cnt         Depthm         T_degC  \
# count  864863.000000  864863.000000  864863.000000  853900.000000
# mean    17138.790958  432432.000000     226.831951      10.799677
# std     10240.949817  249664.587267     316.050259       4.243825
# min         1.000000       1.000000       0.000000       1.440000
# 25%      8269.000000  216216.500000      46.000000       7.680000
# 50%     16848.000000  432432.000000     125.000000      10.060000
# 75%     26557.000000  648647.500000     300.000000      13.880000
# max     34404.000000  864863.000000    5351.000000      31.140000
#
#               Salnty         O2ml_L         STheta          O2Sat  \
# count  817509.000000  696201.000000  812174.000000  661274.000000
# mean       33.840350       3.392468      25.819394      57.103779
# std         0.461843       2.073256       1.167787      37.094137
# min        28.431000      -0.010000      20.934000      -0.100000
# ...

# %%
bottle_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864863 entries, 0 to 864862
# Data columns (total 74 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Cst_Cnt              864863 non-null  int64
#  1   Btl_Cnt              864863 non-null  int64
#  2   Sta_ID               864863 non-null  object
#  3   Depth_ID             864863 non-null  object
#  4   Depthm               864863 non-null  int64
#  5   T_degC               853900 non-null  float64
#  6   Salnty               817509 non-null  float64
#  7   O2ml_L               696201 non-null  float64
#  8   STheta               812174 non-null  float64
#  9   O2Sat                661274 non-null  float64
#  10  Oxy_µmol/Kg          661268 non-null  float64
#  11  BtlNum               118667 non-null  float64
#  12  RecInd               864863 non-null  int64
#  13  T_prec               853900 non-null  float64
# ...

# %%
#Drop columns with lots of missing values (67-73)
bottle_df.drop(bottle_df.iloc[:, 67:74], axis=1, inplace=True)

# %%
bottle_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864863 entries, 0 to 864862
# Data columns (total 67 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Cst_Cnt      864863 non-null  int64
#  1   Btl_Cnt      864863 non-null  int64
#  2   Sta_ID       864863 non-null  object
#  3   Depth_ID     864863 non-null  object
#  4   Depthm       864863 non-null  int64
#  5   T_degC       853900 non-null  float64
#  6   Salnty       817509 non-null  float64
#  7   O2ml_L       696201 non-null  float64
#  8   STheta       812174 non-null  float64
#  9   O2Sat        661274 non-null  float64
#  10  Oxy_µmol/Kg  661268 non-null  float64
#  11  BtlNum       118667 non-null  float64
#  12  RecInd       864863 non-null  int64
#  13  T_prec       853900 non-null  float64
#  14  T_qual       23127 non-null   float64
#  15  S_prec       817509 non-null  float64
#  16  S_qual       74914 non-null   float64
# ...

# %%
#look at object columns (Sta_ID, Depth_ID, IncTim)
bottle_df[['Sta_ID', 'Depth_ID', 'IncTim']].head()
# Out:
#         Sta_ID                                Depth_ID IncTim
# 0  054.0 056.0  19-4903CR-HY-060-0930-05400560-0000A-3    NaN
# 1  054.0 056.0  19-4903CR-HY-060-0930-05400560-0008A-3    NaN
# 2  054.0 056.0  19-4903CR-HY-060-0930-05400560-0010A-7    NaN
# 3  054.0 056.0  19-4903CR-HY-060-0930-05400560-0019A-3    NaN
# 4  054.0 056.0  19-4903CR-HY-060-0930-05400560-0020A-7    NaN

# %%
#Remove object columns since they are not necessary for our research
bottle_df.drop(['Sta_ID', 'Depth_ID', 'IncTim'], axis=1, inplace=True)

# %%
bottle_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864863 entries, 0 to 864862
# Data columns (total 64 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Cst_Cnt      864863 non-null  int64
#  1   Btl_Cnt      864863 non-null  int64
#  2   Depthm       864863 non-null  int64
#  3   T_degC       853900 non-null  float64
#  4   Salnty       817509 non-null  float64
#  5   O2ml_L       696201 non-null  float64
#  6   STheta       812174 non-null  float64
#  7   O2Sat        661274 non-null  float64
#  8   Oxy_µmol/Kg  661268 non-null  float64
#  9   BtlNum       118667 non-null  float64
#  10  RecInd       864863 non-null  int64
#  11  T_prec       853900 non-null  float64
#  12  T_qual       23127 non-null   float64
#  13  S_prec       817509 non-null  float64
#  14  S_qual       74914 non-null   float64
#  15  P_qual       673755 non-null  float64
#  16  O_qual       184676 non-null  float64
# ...

# %%
#Drop columns with lots of missing values
bottle_df.dropna(axis=1, thresh=600000, inplace=True)

# %%
bottle_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864863 entries, 0 to 864862
# Data columns (total 30 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Cst_Cnt      864863 non-null  int64
#  1   Btl_Cnt      864863 non-null  int64
#  2   Depthm       864863 non-null  int64
#  3   T_degC       853900 non-null  float64
#  4   Salnty       817509 non-null  float64
#  5   O2ml_L       696201 non-null  float64
#  6   STheta       812174 non-null  float64
#  7   O2Sat        661274 non-null  float64
#  8   Oxy_µmol/Kg  661268 non-null  float64
#  9   RecInd       864863 non-null  int64
#  10  T_prec       853900 non-null  float64
#  11  S_prec       817509 non-null  float64
#  12  P_qual       673755 non-null  float64
#  13  Chlqua       639166 non-null  float64
#  14  Phaqua       639170 non-null  float64
#  15  NH3q         808299 non-null  float64
#  16  C14A1q       848605 non-null  float64
# ...

# %%
#Drop columns that give NA during correlation
bottle_df.drop(bottle_df.iloc[:, 13:20], axis=1, inplace=True)

# %%
bottle_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864863 entries, 0 to 864862
# Data columns (total 23 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Cst_Cnt      864863 non-null  int64
#  1   Btl_Cnt      864863 non-null  int64
#  2   Depthm       864863 non-null  int64
#  3   T_degC       853900 non-null  float64
#  4   Salnty       817509 non-null  float64
#  5   O2ml_L       696201 non-null  float64
#  6   STheta       812174 non-null  float64
#  7   O2Sat        661274 non-null  float64
#  8   Oxy_µmol/Kg  661268 non-null  float64
#  9   RecInd       864863 non-null  int64
#  10  T_prec       853900 non-null  float64
#  11  S_prec       817509 non-null  float64
#  12  P_qual       673755 non-null  float64
#  13  R_Depth      864863 non-null  float64
#  14  R_TEMP       853900 non-null  float64
#  15  R_POTEMP     818816 non-null  float64
#  16  R_SALINITY   817509 non-null  float64
# ...

# %%
#Check for rows with any remaining missing values left. 
bottle_df.isnull().sum()
# Out:
# Cst_Cnt             0
# Btl_Cnt             0
# Depthm              0
# T_degC          10963
# Salnty          47354
# O2ml_L         168662
# STheta          52689
# O2Sat          203589
# Oxy_µmol/Kg    203595
# RecInd              0
# T_prec          10963
# S_prec          47354
# P_qual         191108
# R_Depth             0
# R_TEMP          10963
# R_POTEMP        46047
# R_SALINITY      47354
# R_SIGMA         52856
# R_SVA           52771
# R_DYNHT         46657
# R_O2           168662
# R_O2Sat        198415
# R_PRES              0
# dtype: int64

# %%
#Fill in missing values with the mean of column
bottle_df.fillna(bottle_df.mean(), inplace=True)

# %%
#Look at remaining dataframe
#Check for rows with any remaining missing values left. 
bottle_df.isnull().sum()
# Out:
# Cst_Cnt        0
# Btl_Cnt        0
# Depthm         0
# T_degC         0
# Salnty         0
# O2ml_L         0
# STheta         0
# O2Sat          0
# Oxy_µmol/Kg    0
# RecInd         0
# T_prec         0
# S_prec         0
# P_qual         0
# R_Depth        0
# R_TEMP         0
# R_POTEMP       0
# R_SALINITY     0
# R_SIGMA        0
# R_SVA          0
# R_DYNHT        0
# R_O2           0
# R_O2Sat        0
# R_PRES         0
# dtype: int64

# %% [markdown]
# # Question 2.	Create a correlation matrix to see how the features are correlated. Describe your findings. Pay particular attention to what is correlated with water temperature.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#Create Cast Correlation Matrix
CastCorrMatrix = cast_df.corr()

plt.figure(figsize=(10,8))
sns.heatmap(CastCorrMatrix)
plt.show()

# %%
#Create Cast Correlation Matrix
BottleCorrMatrix = bottle_df.corr()
print(BottleCorrMatrix)
plt.figure(figsize=(8,8))
sns.heatmap(BottleCorrMatrix)
plt.show()
# Out:
#               Cst_Cnt   Btl_Cnt    Depthm    T_degC    Salnty    O2ml_L  \
# Cst_Cnt      1.000000  0.999345 -0.162222  0.088783 -0.189893  0.146288
# Btl_Cnt      0.999345  1.000000 -0.161617  0.089581 -0.187243  0.144570
# Depthm      -0.162222 -0.161617  1.000000 -0.678628  0.543326 -0.532769
# T_degC       0.088783  0.089581 -0.678628  1.000000 -0.489967  0.712731
# Salnty      -0.189893 -0.187243  0.543326 -0.489967  1.000000 -0.722056
# O2ml_L       0.146288  0.144570 -0.532769  0.712731 -0.722056  1.000000
# STheta      -0.085748 -0.085408  0.551689 -0.804295  0.601137 -0.674994
# O2Sat        0.122815  0.121268 -0.512682  0.745131 -0.708407  0.965814
# Oxy_µmol/Kg  0.132695  0.130957 -0.507193  0.696899 -0.738975  0.972406
# RecInd      -0.100142 -0.100828  0.082316 -0.066060  0.065183 -0.069505
# T_prec       0.067562  0.062489  0.019348 -0.041076 -0.018522  0.001016
# S_prec       0.439404  0.438148  0.005630 -0.034964 -0.079280  0.023181
# ...

# %% [markdown]
# Based on the correlation matrix from above, water temperature (T_degC) is strongly negatively correlated to R_pres (reported pressure), R_Dynht (reported dynamic height), R_sigma (reported potential density of water), R_Depth (reported depth), STheta (potential density of water), and DepthM (depth in meters).  Water temperature (T_degC) is strongly positively correlated to R_O2Sat (reported oxygen saturation), R_O2 (reported milliliters of oxygen per liter of seawater), R_SVA (reported specific volume anamoly), R_Potemp (reported potential temperature), R_Temp (reported temperature), Oxy_umol/kg (Oxygen in micro moles per kilogram of seawater), O2Sat (Oxygen saturation), and O2ml_L (milliliters of dissolved oxygen per liter seawater).

# %% [markdown]
# # Question 3.	Perform linear regression on the dataset to see if you can predict water temperature based on salinity.

# %%
#Set your X (independent) and y (dependant) variables for the linear regression
X = np.array(bottle_df['Salnty']).reshape(-1,1)
y = np.array(bottle_df['T_degC']).reshape(-1,1)

# %%
#import necessary modules

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

#split the data into a training and testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=45)

# %%
reg=LinearRegression()

# %%
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)

# %%
accuracy_score = reg.score(X_test, y_test)
print(accuracy_score)
# Out:
# 0.23922891207816233

# %%
#try after standardizing the data
bottle_df_subset = bottle_df[['Salnty','T_degC']]

# %%
#Standardize the dataset using StandardScaler and save as standardized df
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
standardized_cols = std.fit_transform(bottle_df_subset)
standardized_df = pd.DataFrame(standardized_cols)
standardized_df.columns = ['Salnty','T_degC']
standardized_df.head()
# Out:
#      Salnty    T_degC
# 0 -0.891606 -0.071067
# 1 -0.891606 -0.080552
# 2 -0.898287 -0.080552
# 3 -0.936148 -0.082924
# 4 -0.933920 -0.082924

# %%
#Set your X (independent) and y (dependant) variables for the linear regression
X = np.array(standardized_df['Salnty']).reshape(-1,1)
y = np.array(standardized_df['T_degC']).reshape(-1,1)

# %%
#split the data into a training and testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=45)

# %%
reg=LinearRegression()

# %%
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)

# %%
accuracy_score = reg.score(X_test, y_test)
print(accuracy_score)
# Out:
# 0.2392289120781621

# %% [markdown]
# It does not seem that predicting water temperature based on salinity works well.  The accuracy score is low (0.239) and I tried it both before and after standardizing the dataset, which did not improve the results.

# %% [markdown]
# # Question 4.	Find your mean squared error and R2 values. Be sure to indicate what these tell you. You can import these from sklearn.metrics .

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

r2_score(y_test, y_pred)
# Out:
# 0.2392289120781621

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 0.7595491463206933

# %% [markdown]
# The r2 score gives you the same result as the accuracy score from above.  R2 is the proportion of variance in the dependent variable that is predicted by the independent variable.  In this case, the dependent variable in the water temperature and the independent variable is the salinity. So, these results show that the salinity of the water can not reliably be used to predict the water temperature.  Linear regression predicts a line with the formula y=mx+b that will best fit the data points.  How far each data point is from that line is called the residual. Mean-Squared error is the mean of the squares of the residuals. They are squared since some are negative and some are positive. This gives an idea of how far away the prediction is from the test values. In our case, the number is high, meaning the prediction is not very good.

# %% [markdown]
# # Question 5.	Create a final plot of the relationship between water temperature and salinity. Be sure to show the values from the dataset in a scatter plot with a trend line that shows the predicted temperature values.

# %%
plt.scatter(X_test, y_test, color = 'm')
plt.plot(X_test, y_pred, color='b')
plt.show()

# %% [markdown]
# # Question 6.	Do some research on polynomial regression. Describe what it is any how it works in markdown. This article is useful https://machinelearningmastery.com/polynomial-features-transforms-for-machine-learning/
#
# Polynomial regression is when a polynomial function is predicted based on the training data. This is used when the relationship between the independent and dependent variable is not a linear relationship, but rather better represented as an nth degree polynomial.  The polynomial function is then compared to the test data to see how well the function fits to the test data.

# %% [markdown]
# # Question 7.	Perform polynomial regression on this same dataset. Train and validate your model as you did when you used linear regression. Mean squared error and R2 both apply here.

# %%
X = np.array(bottle_df['Salnty']).reshape(-1,1)
y = np.array(bottle_df['T_degC']).reshape(-1,1)

#X = bottle_df[['Salnty']]
#y = bottle_df.T_degC

# %%
#split the data into a training and testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=45)

# %%
plt.scatter(X,y)
plt.xlabel('Salinity')
plt.ylabel('T_degC')
# Out:
# Text(0, 0.5, 'T_degC')

# %%
from numpy import asarray
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=7)
X_poly_train = poly.fit_transform(X_train)
X_poly_test = poly.fit_transform(X_test)

# %%
poly_model=LinearRegression()

# %%
poly_model.fit(X_poly_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = poly_model.predict(X_poly_test)

# %%
accuracy_score = poly_model.score(X_poly_test, y_test)
print(accuracy_score)
# Out:
# 0.3936817362582832

# %%
plt.scatter(X_test,y_test, c="black")
plt.xlabel('Salinity')
plt.ylabel('T_degC')
plt.plot(X_test, y_pred)

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 10.764071681182616

# %%
r2_score(y_test, y_pred)
# Out:
# 0.3936817362582832

# %% [markdown]
# The polynomial fit improved the r-squared value/accuracy score (0.39) over linear regression.  I changed the degree from 1-9 and evaluated the results and after about 7 degrees, the accuracy score no longer increased significatly.  There is a large computing cost to increasing the number of degrees, so it is important to find a balance between improving your model without increasing the computing time too much.

# %% [markdown]
# # Question 8. Create a final plot of the relationship between water temperature and salinity. Be sure to show the values from the dataset in a scatter plot with a trend line that shows the polynomial regression predicted temperature values. The resulting trend line should be curved.

# %%
plt.scatter(X_test,y_test, c="black")
plt.xlabel('Salinity')
plt.ylabel('T_degC')
plt.plot(X_test, y_pred)
